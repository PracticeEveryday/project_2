# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('mode.chained_assignment',  None) # <==== 경고를 끈다

# %%
df = pd.read_csv('./2018.csv')
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# 1             1.582                    0.861                         0.686
# 2             1.590                    0.868                         0.683
# 3             1.644                    0.914                         0.677
# 4             1.549                    0.927                         0.660
# ..              ...                      ...                           ...
# 151           1.073                    0.343                         0.244
# 152           0.991                    0.381                         0.481
# 153           0.608                    0.177                         0.112
# 154           0.000                    0.010                         0.305
# 155           0.627                    0.145                         0.065
#
#      Generosity  Perceptions of corruption
# 0         0.202                      0.393
# 1         0.286                      0.340
# 2         0.284                      0.408
# 3         0.353                      0.138
# 4         0.256                      0.357
# ..          ...                        ...
# 151       0.083                      0.064
# 152       0.270                      0.097
# 153       0.224                      0.106
# 154       0.218                      0.038
# 155       0.149                      0.076
#
# [156 rows x 9 columns]

# %%
df =  df[['Overall rank','Healthy life expectancy']]
df
# Out:
#      Overall rank  Healthy life expectancy
# 0               1                    0.874
# 1               2                    0.861
# 2               3                    0.868
# 3               4                    0.914
# 4               5                    0.927
# ..            ...                      ...
# 151           152                    0.343
# 152           153                    0.381
# 153           154                    0.177
# 154           155                    0.010
# 155           156                    0.145
#
# [156 rows x 2 columns]

# %%
df.rename(columns = {'Healthy life expectancy':'Health'},inplace=True)
df
# Out:
#      Overall rank  Health
# 0               1   0.874
# 1               2   0.861
# 2               3   0.868
# 3               4   0.914
# 4               5   0.927
# ..            ...     ...
# 151           152   0.343
# 152           153   0.381
# 153           154   0.177
# 154           155   0.010
# 155           156   0.145
#
# [156 rows x 2 columns]

# %%
average = []

for x in range(0, 157, 10) :
    start = x
    end  = x + 10
    temp = df[(df['Overall rank'] >= start) & (df['Health'] < end)]
    print("{}이상 {}미만 : {}".format(start, end, temp['Health'].mean()))
    average.append(temp['Health'].mean())
# Out:
# 0이상 10미만 : 0.5973461538461537
# 10이상 20미만 : 0.5794489795918367
# 20이상 30미만 : 0.557985401459854
# 30이상 40미만 : 0.5395590551181104
# 40이상 50미만 : 0.5226239316239318
# 50이상 60미만 : 0.5064112149532711
# 60이상 70미만 : 0.4782371134020618
# 70이상 80미만 : 0.4582528735632184
# 80이상 90미만 : 0.4271688311688313
# 90이상 100미만 : 0.3877611940298509
# 100이상 110미만 : 0.37389473684210534
# 110이상 120미만 : 0.35163829787234047
# 120이상 130미만 : 0.3232162162162162
# 130이상 140미만 : 0.28818518518518516
# 140이상 150미만 : 0.27870588235294114
# 150이상 160미만 : 0.28500000000000003

# %%
average
# Out:
# [0.5973461538461537,
#  0.5794489795918367,
#  0.557985401459854,
#  0.5395590551181104,
#  0.5226239316239318,
#  0.5064112149532711,
#  0.4782371134020618,
#  0.4582528735632184,
#  0.4271688311688313,
#  0.3877611940298509,
#  0.37389473684210534,
#  0.35163829787234047,
#  0.3232162162162162,
#  0.28818518518518516,
#  0.27870588235294114,
#  0.28500000000000003]

# %%
average
x = np.arange(16)

# %%
plt.plot(x, average)
