# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('mode.chained_assignment',  None) # <==== 경고를 끈다

# %%
df = pd.read_csv('./2019.csv')
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df =  df[['Overall rank','Healthy life expectancy']]
df
# Out:
#      Overall rank  Healthy life expectancy
# 0               1                    0.986
# 1               2                    0.996
# 2               3                    1.028
# 3               4                    1.026
# 4               5                    0.999
# ..            ...                      ...
# 151           152                    0.614
# 152           153                    0.499
# 153           154                    0.361
# 154           155                    0.105
# 155           156                    0.295
#
# [156 rows x 2 columns]

# %%
df.rename(columns = {'Healthy life expectancy' : 'Health'}, inplace = True)
df
# Out:
#      Overall rank  Health
# 0               1   0.986
# 1               2   0.996
# 2               3   1.028
# 3               4   1.026
# 4               5   0.999
# ..            ...     ...
# 151           152   0.614
# 152           153   0.499
# 153           154   0.361
# 154           155   0.105
# 155           156   0.295
#
# [156 rows x 2 columns]

# %%
average = []

for x in range(0, 157, 10) :
    start = x
    end  = x + 10
    temp = df[(df['Overall rank'] >= start) & (df['Health'] < end)]
    print("{}이상 {}미만 : {}".format(start, end, temp['Health'].mean()))
    average.append(temp['Health'].mean())
# Out:
# 0이상 10미만 : 0.7252435897435898
# 10이상 20미만 : 0.7073265306122453
# 20이상 30미만 : 0.6867080291970805
# 30이상 40미만 : 0.6707322834645669
# 40이상 50미만 : 0.6502905982905981
# 50이상 60미만 : 0.6307570093457943
# 60이상 70미만 : 0.6053608247422678
# 70이상 80미만 : 0.5846781609195398
# 80이상 90미만 : 0.5525194805194804
# 90이상 100미만 : 0.5258358208955224
# 100이상 110미만 : 0.504824561403509
# 110이상 120미만 : 0.4781063829787235
# 120이상 130미만 : 0.45972972972972975
# 130이상 140미만 : 0.44825925925925925
# 140이상 150미만 : 0.4312352941176471
# 150이상 160미만 : 0.40457142857142864

# %%
average
# Out:
# [0.7252435897435898,
#  0.7073265306122453,
#  0.6867080291970805,
#  0.6707322834645669,
#  0.6502905982905981,
#  0.6307570093457943,
#  0.6053608247422678,
#  0.5846781609195398,
#  0.5525194805194804,
#  0.5258358208955224,
#  0.504824561403509,
#  0.4781063829787235,
#  0.45972972972972975,
#  0.44825925925925925,
#  0.4312352941176471,
#  0.40457142857142864]

# %%
average
x = np.arange(16)

# %%
plt.plot(x, average)
plt.show()
