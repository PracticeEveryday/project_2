# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('mode.chained_assignment',  None) # <==== 경고를 끈다

# %%
df = pd.read_csv('./2017.csv')
df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 0       7.479556                  1.616463  1.533524
# 1       7.462272                  1.482383  1.551122
# 2       7.385970                  1.480633  1.610574
# 3       7.426227                  1.564980  1.516912
# 4       7.410458                  1.443572  1.540247
# ..           ...                       ...       ...
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 0                    0.796667  0.635423    0.362012
# 1                    0.792566  0.626007    0.355280
# 2                    0.833552  0.627163    0.475540
# 3                    0.858131  0.620071    0.290549
# 4                    0.809158  0.617951    0.245483
# ..                        ...       ...         ...
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# 152                  0.364509  0.390018    0.354256
# 153                  0.151611  0.059901    0.204435
# 154                  0.018773  0.270842    0.280876
#
#      Trust..Government.Corruption.  Dystopia.Residual
# 0                         0.315964           2.277027
# 1                         0.400770           2.313707
# 2                         0.153527           2.322715
# 3                         0.367007           2.276716
# 4                         0.382612           2.430182
# ..                             ...                ...
# 150                       0.455220           0.540061
# 151                       0.151347           1.061574
# 152                       0.066035           0.621130
# 153                       0.084148           1.683024
# 154                       0.056565           2.066005
#
# [155 rows x 12 columns]

# %%
df =  df[['Happiness.Rank','Health..Life.Expectancy.']]
df
# Out:
#      Happiness.Rank  Health..Life.Expectancy.
# 0                 1                  0.796667
# 1                 2                  0.792566
# 2                 3                  0.833552
# 3                 4                  0.858131
# 4                 5                  0.809158
# ..              ...                       ...
# 150             151                  0.326425
# 151             152                  0.500533
# 152             153                  0.364509
# 153             154                  0.151611
# 154             155                  0.018773
#
# [155 rows x 2 columns]

# %%
df.rename(columns = {'Health..Life.Expectancy.':'Health'},inplace=True)
df
# Out:
#      Happiness.Rank    Health
# 0                 1  0.796667
# 1                 2  0.792566
# 2                 3  0.833552
# 3                 4  0.858131
# 4                 5  0.809158
# ..              ...       ...
# 150             151  0.326425
# 151             152  0.500533
# 152             153  0.364509
# 153             154  0.151611
# 154             155  0.018773
#
# [155 rows x 2 columns]

# %%
average = []

for x in range(0, 157, 10) :
    start = x
    end  = x + 10
    temp = df[(df['Happiness.Rank'] >= start) & (df['Health'] < end)]
    print("{}이상 {}미만 : {}".format(start, end, temp['Health'].mean()))
    average.append(temp['Health'].mean())
# Out:
# 0이상 10미만 : 0.5513407826123219
# 10이상 20미만 : 0.5347593120197217
# 20이상 30미만 : 0.5144573072834379
# 30이상 40미만 : 0.49692785688897684
# 40이상 50미만 : 0.48004086876834007
# 50이상 60미만 : 0.4638405472725489
# 60이상 70미만 : 0.44616807185229845
# 70이상 80미만 : 0.4185706092326274
# 80이상 90미만 : 0.3873478103012435
# 90이상 100미만 : 0.3515901131357885
# 100이상 110미만 : 0.3279726186467867
# 110이상 120미만 : 0.2979428113397697
# 120이상 130미만 : 0.2816939891522957
# 130이상 140미만 : 0.24457110643673405
# 140이상 150미만 : 0.24633852124679825
# 150이상 160미만 : 0.2681594133997956

# %%
average
# Out:
# [0.5513407826123219,
#  0.5347593120197217,
#  0.5144573072834379,
#  0.49692785688897684,
#  0.48004086876834007,
#  0.4638405472725489,
#  0.44616807185229845,
#  0.4185706092326274,
#  0.3873478103012435,
#  0.3515901131357885,
#  0.3279726186467867,
#  0.2979428113397697,
#  0.2816939891522957,
#  0.24457110643673405,
#  0.24633852124679825,
#  0.2681594133997956]

# %%
average
x = np.arange(16)

# %%
plt.plot(x, average)
