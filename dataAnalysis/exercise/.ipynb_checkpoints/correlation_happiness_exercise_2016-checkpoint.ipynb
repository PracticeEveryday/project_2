# %%
import pandas as pd
import numpy as np
pd.set_option('mode.chained_assignment',  None) # <==== 경고를 끈다import matplotlib.pyplot as plt

# %%
pd.set_option('mode.chained_assignment',  None) # <==== 경고를 끈다

# %%
df = pd.read_csv('./2016.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
df =  df[['Happiness Rank','Health (Life Expectancy)']]
df
# Out:
#      Happiness Rank  Health (Life Expectancy)
# 0                 1                   0.79504
# 1                 2                   0.86303
# 2                 3                   0.86733
# 3                 4                   0.79579
# 4                 5                   0.81091
# ..              ...                       ...
# 152             153                   0.21028
# 153             154                   0.17344
# 154             155                   0.24811
# 155             156                   0.62994
# 156             157                   0.15747
#
# [157 rows x 2 columns]

# %%
df.rename(columns = {'Health (Life Expectancy)':'Health'},inplace=True)
df
# Out:
#      Happiness Rank   Health
# 0                 1  0.79504
# 1                 2  0.86303
# 2                 3  0.86733
# 3                 4  0.79579
# 4                 5  0.81091
# ..              ...      ...
# 152             153  0.21028
# 153             154  0.17344
# 154             155  0.24811
# 155             156  0.62994
# 156             157  0.15747
#
# [157 rows x 2 columns]

# %%
average = []

for x in range(0, 157, 10) :
    start = x
    end  = x + 10
    temp = df[(df['Happiness Rank'] >= start) & (df['Health'] < end)]
    print("{}이상 {}미만 : {}".format(start, end, temp['Health'].mean()))
    average.append(temp['Health'].mean())
# Out:
# 0이상 10미만 : 0.5576189808917195
# 10이상 20미만 : 0.5411622297297295
# 20이상 30미만 : 0.5233679710144927
# 30이상 40미만 : 0.5036798437500001
# 40이상 50미만 : 0.48679016949152537
# 50이상 60미만 : 0.4760837962962962
# 60이상 70미만 : 0.45689500000000005
# 70이상 80미만 : 0.4332017045454544
# 80이상 90미만 : 0.411968205128205
# 90이상 100미만 : 0.38467397058823516
# 100이상 110미만 : 0.3429749999999999
# 110이상 120미만 : 0.3148241666666666
# 120이상 130미만 : 0.3051265789473684
# 130이상 140미만 : 0.25197
# 140이상 150미만 : 0.2521188888888889
# 150이상 160미만 : 0.26972875

# %%
average
# Out:
# [0.5576189808917195,
#  0.5411622297297295,
#  0.5233679710144927,
#  0.5036798437500001,
#  0.48679016949152537,
#  0.4760837962962962,
#  0.45689500000000005,
#  0.4332017045454544,
#  0.411968205128205,
#  0.38467397058823516,
#  0.3429749999999999,
#  0.3148241666666666,
#  0.3051265789473684,
#  0.25197,
#  0.2521188888888889,
#  0.26972875]

# %%
average
x = np.arange(16)

# %%
plt.plot(x, average)
